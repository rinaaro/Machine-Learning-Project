# %%
import os
import pandas as pd

# %%
for file_name in os.listdir("files"):
    if file_name.endswith('.csv'):
        file_path = os.path.join("files", file_name)

        df_name = os.path.splitext(file_name)[0]
        globals()[df_name] = pd.read_csv(file_path)

# %% [markdown]
# ## SIMPLIFY CATEGORICAL VARIABLES

# %% [markdown]
# SPORT VARIABLE

# %%
learn_dataset_sport = pd.merge(learn_dataset_sport, code_Sports, left_on="Sports", right_on="Code")
learn_dataset_sport["Sports_Category"] = learn_dataset_sport["Categorie"]
learn_sports = learn_dataset_sport[["PRIMARY_KEY", "Sports_Category"]]

# %% [markdown]
# WORK_DESCRIPTION_VARIABLE

# %%
learn_dataset_work_description = pd.merge(learn_dataset_job, code_work_description_map, left_on="work_description", right_on="N3")
learn_work_des = learn_dataset_work_description[["PRIMARY_KEY","N1"]]

# %%
learn_dataset_work_description
# Out:
#        PRIMARY_KEY Employer_category employee_count    Pay Economic_sector  \
# 0                1              ct_9           tr_1  17011              LZ
# 1                8              ct_9           tr_1  57220              CG
# 2               16              ct_9           tr_6  53942              QA
# 3               18              ct_9           tr_1   2012              NZ
# 4               40              ct_9           tr_6  16804              NZ
# ...            ...               ...            ...    ...             ...
# 19132       100057              ct_9           tr_1  18881              IZ
# 19133       100059              ct_6           tr_2  28352              GZ
# 19134       100078              ct_8           tr_6  15890              QA
# 19135       100079              ct_8           tr_4  47552              QB
# 19136       100082              ct_9           tr_3   6097              CE
#
#       TYPE_OF_CONTRACT WORK_CONDITION labor_force_status  WORKING_HOURS  \
# 0                  CDI              C                  O         1470.0
# 1                  CDI              C                  O         1201.0
# 2                  CDI              C                  O         1820.0
# 3                  TTP              C                  O          352.0
# 4                  CDI              C                  O         1820.0
# ...                ...            ...                ...            ...
# 19132              CDI              C                  O         1659.0
# 19133              CDI              C                  O         1806.0
# 19134              CDI              P                  O          665.0
# 19135              CDI              C                  O         3000.0
# 19136              CDI              C                  O         1796.0
#
#       work_description JOB_DEP    N3       N2     N1
# 0                 543f      01  543f  csp_5_4  csp_5
# 1                 376d      92  376d  csp_3_7  csp_3
# 2                 431a      01  431a  csp_4_3  csp_4
# 3                 652a      01  652a  csp_6_5  csp_6
# 4                 684a      71  684a  csp_6_8  csp_6
# ...                ...     ...   ...      ...    ...
# 19132             561d      95  561d  csp_5_6  csp_5
# 19133             433d      95  433d  csp_4_3  csp_4
# 19134             433a      94  433a  csp_4_3  csp_4
# 19135             526a      92  526a  csp_5_2  csp_5
# 19136             625c      95  625c  csp_6_2  csp_6
#
# [19137 rows x 14 columns]

# %%
learn_work_des
# Out:
#        PRIMARY_KEY     N1
# 0                1  csp_5
# 1                8  csp_3
# 2               16  csp_4
# 3               18  csp_6
# 4               40  csp_6
# ...            ...    ...
# 19132       100057  csp_5
# 19133       100059  csp_4
# 19134       100078  csp_4
# 19135       100079  csp_5
# 19136       100082  csp_6
#
# [19137 rows x 2 columns]

# %% [markdown]
# JOB_DEP_VARIABLE

# %%
learn_dataset_job_dep = pd.merge(learn_dataset_job, departments, left_on="JOB_DEP", right_on="DEP")
learn_dataset_job_dep["REG_JOB"] = learn_dataset_job_dep["REG"]
learn_reg = learn_dataset_job_dep[["PRIMARY_KEY", "REG_JOB"]]

# %%
learn_dataset_job_dep
# Out:
#        PRIMARY_KEY Employer_category employee_count    Pay Economic_sector  \
# 0                1              ct_9           tr_1  17011              LZ
# 1                8              ct_9           tr_1  57220              CG
# 2               16              ct_9           tr_6  53942              QA
# 3               18              ct_9           tr_1   2012              NZ
# 4               40              ct_9           tr_6  16804              NZ
# ...            ...               ...            ...    ...             ...
# 19110       100057              ct_9           tr_1  18881              IZ
# 19111       100059              ct_6           tr_2  28352              GZ
# 19112       100078              ct_8           tr_6  15890              QA
# 19113       100079              ct_8           tr_4  47552              QB
# 19114       100082              ct_9           tr_3   6097              CE
#
#       TYPE_OF_CONTRACT WORK_CONDITION labor_force_status  WORKING_HOURS  \
# 0                  CDI              C                  O         1470.0
# 1                  CDI              C                  O         1201.0
# 2                  CDI              C                  O         1820.0
# 3                  TTP              C                  O          352.0
# 4                  CDI              C                  O         1820.0
# ...                ...            ...                ...            ...
# 19110              CDI              C                  O         1659.0
# 19111              CDI              C                  O         1806.0
# 19112              CDI              P                  O          665.0
# 19113              CDI              C                  O         3000.0
# 19114              CDI              C                  O         1796.0
#
#       work_description JOB_DEP Nom du département  REG DEP  REG_JOB
# 0                 543f      01                Ain   84  01       84
# 1                 376d      92     Hauts-de-Seine   11  92       11
# 2                 431a      01                Ain   84  01       84
# 3                 652a      01                Ain   84  01       84
# 4                 684a      71     Saône-et-Loire   27  71       27
# ...                ...     ...                ...  ...  ..      ...
# 19110             561d      95         Val-d'Oise   11  95       11
# 19111             433d      95         Val-d'Oise   11  95       11
# 19112             433a      94       Val-de-Marne   11  94       11
# 19113             526a      92     Hauts-de-Seine   11  92       11
# 19114             625c      95         Val-d'Oise   11  95       11
#
# [19115 rows x 15 columns]

# %%
learn_reg
# Out:
#        PRIMARY_KEY  REG_JOB
# 0                1       84
# 1                8       11
# 2               16       84
# 3               18       84
# 4               40       27
# ...            ...      ...
# 19110       100057       11
# 19111       100059       11
# 19112       100078       11
# 19113       100079       11
# 19114       100082       11
#
# [19115 rows x 2 columns]

# %% [markdown]
# FORMER_DEP_VARIABLE

# %%
learn_dataset_retired_job_dep = pd.merge(learn_dataset_retired_jobs, departments, left_on="FORMER_DEP", right_on="DEP")
learn_dataset_job_dep["REG_FORMER_JOB"] = learn_dataset_job_dep["REG"]
learn_retired_reg = learn_dataset_job_dep[["PRIMARY_KEY", "REG_FORMER_JOB"]]

# %%
learn_dataset_retired_job_dep
# Out:
#        PRIMARY_KEY Economic_sector FORMER_DEP JOB_DEP work_description  \
# 0                5              GZ         67      67             634a
# 1               19              FZ         93      78             621b
# 2               21              CM         77      89             431f
# 3               25              MB         64      64             387b
# 4               38              QB         60      60             525d
# ...            ...             ...        ...     ...              ...
# 10877       100044              IZ         2B      2B             561e
# 10878       100048              QA         95      95             542a
# 10879       100053              TZ         13      13             563c
# 10880       100067              GZ         69      69             643a
# 10881       100076              GZ         06      06             554a
#
#       TYPE_OF_CONTRACT labor_force_status WORK_CONDITION Employer_category  \
# 0                  CDI                  O              C              ct_9
# 1                  CDI                  O              C              ct_9
# 2                  CDI                  O              C              ct_9
# 3                  CDI                  O              P              ct_9
# 4                  CDI                  O              C              ct_9
# ...                ...                ...            ...               ...
# 10877              CDI                  O              C               NaN
# 10878              CDI                  O              C              ct_9
# 10879              CDI                  O              N              ct_7
# 10880              CDI                  O              C              ct_9
# 10881              CDI                  O              C              ct_9
#
#        WORKING_HOURS employee_count    Nom du département  REG DEP
# 0              793.0           tr_1              Bas-Rhin   44  67
# 1             1750.0           tr_6     Seine-Saint-Denis   11  93
# 2             1872.0           tr_6        Seine-et-Marne   11  77
# 3              781.0           tr_6  Pyrénées-Atlantiques   75  64
# 4             1785.0           tr_4                  Oise   32  60
# ...              ...            ...                   ...  ...  ..
# 10877          211.0            NaN           Haute-Corse   94  2B
# 10878         1820.0           tr_6            Val-d'Oise   11  95
# 10879         1931.0           tr_1      Bouches-du-Rhône   93  13
# 10880         1586.0           tr_2                 Rhône   84  69
# 10881         1820.0           tr_1       Alpes-Maritimes   93  06
#
# [10882 rows x 14 columns]

# %%
learn_retired_reg
# Out:
#        PRIMARY_KEY  REG_FORMER_JOB
# 0                1              84
# 1                8              11
# 2               16              84
# 3               18              84
# 4               40              27
# ...            ...             ...
# 19110       100057              11
# 19111       100059              11
# 19112       100078              11
# 19113       100079              11
# 19114       100082              11
#
# [19115 rows x 2 columns]

# %% [markdown]
# ECONOMIC_SECTOR_VARIABLE

# %%
# Define a function to map NACE codes to their nomenclature
def sector_mapping(nace_code):
    # Check if the code is in the "Industrie (et agriculture)" range (AZ to EZ)
    if "AZ" <= nace_code <= "EZ":  
        return "Industrie (et agriculture)"
    elif nace_code == "FZ":  # Exact match for FZ
        return "Construction"
    elif nace_code == "GZ":  # Exact match for GZ
        return "Commerce"
    elif nace_code == "IZ":  # Exact match for IZ
        return "Hébergement et restauration"
    elif nace_code == "7820Z":  # Exact match for 7820Z
        return "Intérim"
    elif "HZ" <= nace_code <= "UZ" and nace_code != "7820Z":  # Covers HZ to UZ, excluding 7820Z
        return "Autres services hors intérim"
    else:
        return "Unknown Sector"

# %%
learn_dataset_job["Nomenclature"] = learn_dataset_job["Economic_sector"].map(sector_mapping)
learn_nomenclature = learn_dataset_job[["PRIMARY_KEY","Nomenclature"]]

# %%
learn_nomenclature
# Out:
#        PRIMARY_KEY                  Nomenclature
# 0                1  Autres services hors intérim
# 1                8    Industrie (et agriculture)
# 2               16  Autres services hors intérim
# 3               18  Autres services hors intérim
# 4               40  Autres services hors intérim
# ...            ...                           ...
# 19132       100057   Hébergement et restauration
# 19133       100059                      Commerce
# 19134       100078  Autres services hors intérim
# 19135       100079  Autres services hors intérim
# 19136       100082    Industrie (et agriculture)
#
# [19137 rows x 2 columns]

# %% [markdown]
# ## MERGING DATASETS

# %%
learn_dfs = [learn_dataset_emp_contract, learn_dataset_job,learn_dataset_retired_former, learn_dataset_retired_jobs, learn_dataset_retired_pension, learn_sports,learn_work_des,learn_reg, learn_retired_reg,learn_nomenclature]

learn_data = learn_dataset

for df in learn_dfs:
    learn_data = pd.merge(learn_data, df, on="PRIMARY_KEY", how="outer")

# %%
def combine_columns(col_x, col_y):
    return col_x.fillna(col_y) if col_y is not None else col_x

for column in learn_data.columns:
    if column.endswith('_x'):
        base_column = column[:-2]  # Remove `_x` suffix
        y_column = base_column + '_y'
        if y_column in learn_data.columns:
            # Combine the columns
            learn_data[base_column] = combine_columns(learn_data[column], learn_data[y_column])
            # Drop the original `_x` and `_y` columns
            learn_data = learn_data.drop(columns=[column, y_column])

# %%
learn_data.drop(["Economic_sector", "work_description","JOB_DEP", "FORMER_DEP"], axis=1, inplace=True)
learn_data.head(10)
# Out:
#    PRIMARY_KEY     sex   JOB_42 HIGHEST_CREDENTIAL      act  studying  \
# 0            1  Female  csp_5_4           dipl|1|7  TACT1_1     False
# 1            5    Male  csp_7_8           dipl|1|3  TACT2_1     False
# 2            7  Female  csp_3_1           dipl|1|8  TACT1_1     False
# 3            8    Male  csp_3_7           dipl|1|6  TACT1_1     False
# 4           10  Female  csp_5_6           dipl|1|3  TACT1_2     False
# 5           13  Female  csp_4_3           dipl|1|7  TACT1_1     False
# 6           16  Female  csp_4_3           dipl|1|6  TACT1_1     False
# 7           17    Male  csp_1_1           dipl|1|3  TACT1_1     False
# 8           18    Male  csp_6_5           dipl|1|2  TACT1_1     False
# 9           19    Male  csp_7_8             dipl|2  TACT2_1     False
#
#   INSEE_CODE  age_2020 HOUSEHOLD_TYPE     target  ...     N1  REG_JOB  \
# 0      01004        34          M|3|2   9.367020  ...  csp_5     84.0
# 1      01004        80          M|4|4   8.648771  ...    NaN      NaN
# 2      01004        63          M|4|1  10.792503  ...    NaN      NaN
# 3      01004        50          M|4|1   8.508222  ...  csp_3     11.0
# 4      01004        68          M|4|4   8.966272  ...    NaN      NaN
# 5      01004        28          M|4|3  13.301652  ...    NaN      NaN
# 6      01004        58          M|4|1  10.896805  ...  csp_4     84.0
# 7      01004        60          M|4|1   8.453861  ...    NaN      NaN
# 8      01004        56          M|4|1  14.439897  ...  csp_6     84.0
# 9      01004        90          M|1|1   6.577338  ...    NaN      NaN
#
#   REG_FORMER_JOB Employer_category  employee_count  TYPE_OF_CONTRACT  \
# 0           84.0              ct_9            tr_1               CDI
# 1            NaN              ct_9            tr_1               CDI
# 2            NaN               NaN             NaN               NaN
# 3           11.0              ct_9            tr_1               CDI
# 4            NaN               NaN             NaN               NaN
# 5            NaN               NaN             NaN               NaN
# 6           84.0              ct_9            tr_6               CDI
# 7            NaN               NaN             NaN               NaN
# 8           84.0              ct_9            tr_1               TTP
# 9            NaN              ct_9            tr_6               CDI
#
#    WORK_CONDITION labor_force_status  WORKING_HOURS  \
# 0               C                  O         1470.0
# 1               C                  O          793.0
# 2             NaN                NaN            NaN
# 3               C                  O         1201.0
# 4             NaN                NaN            NaN
# 5             NaN                NaN            NaN
# 6               C                  O         1820.0
# 7             NaN                NaN            NaN
# 8               C                  O          352.0
# 9               C                  O         1750.0
#
#                    Nomenclature
# 0  Autres services hors intérim
# 1                           NaN
# 2                           NaN
# 3    Industrie (et agriculture)
# 4                           NaN
# 5                           NaN
# 6  Autres services hors intérim
# 7                           NaN
# 8  Autres services hors intérim
# 9                           NaN
#
# [10 rows x 27 columns]
